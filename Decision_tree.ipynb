# %%
# load the dataset 
# select the target and feature vaariable
# labling the categorical variable
# traning the model

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df= sns.load_dataset('iris')
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
# target and feature variable
X = df.drop(['species'],axis=1)
Y = df['species']

# %% [markdown]
# # incoding the target variable
# from sklearn.preprocessing import LabelEncoder
# label = LabelEncoder()
# Y = label.fit_transform(Y)

# %%
# train & test the model
from sklearn.model_selection import train_test_split as tts
X_train,X_test,y_train,y_test = tts(X,Y,test_size=0.3,random_state= 0)

# %%
print(X_train.shape, y_train.shape ,'\n', X_test.shape, y_test.shape)
# Out:
# (105, 4) (105,)
#  (45, 4) (45,)

# %% [markdown]
# # Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier,plot_tree
dtree = DecisionTreeClassifier()
model = dtree.fit(X_train,y_train)

# %%
model.score(X_train,y_train)
# Out:
# 1.0

# %%
plt.figure(figsize=(10,10))
plot_tree(dtree,filled=True,
                feature_names=df.columns,
                class_names=['setosa','verginica','vercicolor'])
# Out:
# [Text(0.4, 0.9, 'petal_width <= 0.75\ngini = 0.664\nsamples = 105\nvalue = [34, 32, 39]\nclass = vercicolor'),
#  Text(0.3, 0.7, 'gini = 0.0\nsamples = 34\nvalue = [34, 0, 0]\nclass = setosa'),
#  Text(0.5, 0.7, 'petal_length <= 4.95\ngini = 0.495\nsamples = 71\nvalue = [0, 32, 39]\nclass = vercicolor'),
#  Text(0.2, 0.5, 'petal_width <= 1.65\ngini = 0.161\nsamples = 34\nvalue = [0, 31, 3]\nclass = verginica'),
#  Text(0.1, 0.3, 'gini = 0.0\nsamples = 30\nvalue = [0, 30, 0]\nclass = verginica'),
#  Text(0.3, 0.3, 'sepal_width <= 3.1\ngini = 0.375\nsamples = 4\nvalue = [0, 1, 3]\nclass = vercicolor'),
#  Text(0.2, 0.1, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3]\nclass = vercicolor'),
#  Text(0.4, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]\nclass = verginica'),
#  Text(0.8, 0.5, 'petal_length <= 5.05\ngini = 0.053\nsamples = 37\nvalue = [0, 1, 36]\nclass = vercicolor'),
#  Text(0.7, 0.3, 'sepal_length <= 6.5\ngini = 0.375\nsamples = 4\nvalue = [0, 1, 3]\nclass = vercicolor'),
#  Text(0.6, 0.1, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3]\nclass = vercicolor'),
#  Text(0.8, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]\nclass = verginica'),
#  Text(0.9, 0.3, 'gini = 0.0\nsamples = 33\nvalue = [0, 0, 33]\nclass = vercicolor')]
